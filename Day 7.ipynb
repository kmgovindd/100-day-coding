# %% [markdown]
# # NumPy Random

# %% [markdown]
# Random means something that cannot predicted logically

# %% [markdown]
# INDEX
#
# 1. Using rand()
# 2. Gaussian Distribution
# 3. Visualization
# 4. Simple arithemetic
# 5. Rounding Decimal

# %% [markdown]
# # 1.Using rand()

# %%
import numpy as np
from numpy import random
a = random.rand()
b = random.rand(5)
c = random.rand(3, 5)
d = random.choice([1, 2, 5, 7])
e = random.choice([2, 4, 6, 8], size=(2, 4))
f = random.randint(100)
g = random.randint(100, size=(4))
h = random.randint(100, size=(2, 4))
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
# Out:
# 0.08422299602510164
# [0.41820859 0.93961673 0.71371272 0.98350217 0.15567818]
# [[0.22423839 0.886562   0.64762417 0.92003397 0.77143695]
#  [0.74042566 0.76410815 0.14735307 0.44689117 0.79457921]
#  [0.2203413  0.46317813 0.22058544 0.654488   0.41617219]]
# 5
# [[6 8 2 4]
#  [6 6 2 8]]
# 51
# [17 29 61 25]
# [[57 25 62  5]
#  [82 71 23 32]]

# %% [markdown]
# # 2.Gaussian Distribution

# %%
from numpy import random

y1 = random.normal(loc=1, scale=2, size=(2, 3))
y2 = random.binomial(n=10, p=0.5, size=10)
y3 = random.poisson(lam=2, size=10)
y4 = random.uniform(size=(2, 3))
y5 = random.logistic(loc=1, scale=2, size=(2, 3))
y6 = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])
y7 = random.exponential(scale=2, size=(2, 3))
y8 = random.chisquare(df=2, size=(2, 3))
y9 = random.rayleigh(scale=2, size=(2, 3))
y10 = random.pareto(a=2, size=(2, 3))
y11 = random.zipf(a=2, size=(2, 3))


print(y1)
print("----------***----------")
print(y2)
print("----------***----------")
print(y3)
print("----------***----------")
print(y4)
print("----------***----------")
print(y5)
print("----------***----------")
print(y6)
print("----------***----------")
print(y7)
print("----------***----------")
print(y8)
print("----------***----------")
print(y9)
print("----------***----------")
print(y10)
print("----------***----------")
print(y11)
# Out:
# [[-0.15890972  2.29202807  2.03450596]
#  [-2.23727715  2.49533841  0.92549068]]
# ----------***----------
# [6 6 6 4 6 6 4 3 7 5]
# ----------***----------
# [2 1 0 0 2 4 4 4 2 2]
# ----------***----------
# [[0.97349037 0.30933473 0.11763618]
#  [0.52231911 0.47123637 0.89513593]]
# ----------***----------
# [[-5.05791451 -0.13810981 -0.74524698]
#  [ 2.37096374 -0.28115662 -0.55049396]]
# ----------***----------
# [2 0 0 1 1 2]
# ----------***----------
# [[2.7416021  0.35310728 1.8212786 ]
#  [4.14778242 4.79678543 1.40055123]]
# ----------***----------
# [[0.62037962 2.23034158 3.01009563]
#  [5.78087622 0.63104701 1.06605006]]
# ----------***----------
# [[3.41260016 5.39171941 1.70752729]
#  [1.42453615 2.90805521 5.34837593]]
# ----------***----------
# [[3.63475087 2.26749939 0.23572287]
#  [0.17134887 7.46193685 0.67283031]]
# ----------***----------
# [[2 3 1]
#  [2 1 1]]

# %% [markdown]
# # 3.Visualization

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns


# Create subplots to display the distributions using Seaborn
plt.figure(figsize=(12,12))

# Plot Normal distribution
plt.subplot(331)
sns.distplot(random.normal(size=1000), hist=False)
plt.title('Normal Distribution')

# Plot Binomial distribution
plt.subplot(332)
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
plt.title('Binomial Distribution')


# Plot Poisson distribution
plt.subplot(333)
sns.distplot(random.poisson(lam=2, size=1000), kde=False)
plt.title('Poisson distribution')

# Plot uniform distribution
plt.subplot(334)
sns.distplot(random.uniform(size=1000), hist=False)
plt.title('Uniform distribution')

# Plot logistic distribution
plt.subplot(335)
sns.distplot(random.logistic(size=1000), hist=False)
plt.title('logistic distribution')

# Plot multinomial distribution
plt.subplot(336)
sns.distplot(random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6]))
plt.title('multinomial distribution')

# Plot exponential distribution
plt.subplot(337)
sns.distplot(random.exponential(size=1000), hist=False)
plt.title('exponential distribution')

# Plot chisquare distribution
plt.subplot(338)
sns.distplot(random.chisquare(df=1, size=1000), hist=False)
plt.title('Chisquare distribution')

# Plot rayleigh distribution
plt.subplot(339)
sns.distplot(random.rayleigh(size=1000), hist=False)
plt.title('rayleigh distribution')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:16: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:22: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False)
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:27: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=1000), hist=False)
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:32: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000), hist=False)
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:37: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6]))
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:42: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(size=1000), hist=False)
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:47: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=1, size=1000), hist=False)
# C:\Users\kmgov\AppData\Local\Temp\ipykernel_1600\1143792042.py:52: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.rayleigh(size=1000), hist=False)

# %% [markdown]
# # 4.Simple arithemetic

# %% [markdown]
# add()
#
# subtract()
#
# multiply()
#
# divide()
#
# power()
#
# mod()
#
# remainder()
#
# divmod()
#
# absolute()

# %%
import numpy as np

arr1 = np.array([10, 11, 12, 13, 14, 15])
arr2 = np.array([20, 21, 22, 23, 24, 25])

new1 = np.add(arr1, arr2)
new2 = np.subtract(arr1, arr2)
new3 = np.multiply(arr1, arr2)

print(new1)
print(new2)
print(new3)
# Out:
# [30 32 34 36 38 40]
# [-10 -10 -10 -10 -10 -10]
# [200 231 264 299 336 375]

# %%
import numpy as np

arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([3, 5, 10, 8, 2, 33])

new4 = np.divide(arr1, arr2)
new5 = np.power(arr1, arr2)
new6 = np.mod(arr1, arr2)
new7 = np.remainder(arr1, arr2)
new8 = np.divmod(arr1, arr2)

print(new4)
print(new5)
print(new6)
print(new7)
print(new8)
# Out:
# [ 3.33333333  4.          3.          5.         25.          1.81818182]
# [      1000    3200000  716276736 -520093696       2500          0]
# [ 1  0  0  0  0 27]
# [ 1  0  0  0  0 27]
# (array([ 3,  4,  3,  5, 25,  1]), array([ 1,  0,  0,  0,  0, 27]))

# %%
import numpy as np

arr = np.array([-1, -2, 1, 2, 3, -4])
new9 = np.absolute(arr)

print(new9)
# Out:
# [1 2 1 2 3 4]

# %% [markdown]
# # 5.Rounding Decimals

# %%
import numpy as np

arr1 = np.trunc([-3.1666, 3.6667])
arr2 = np.fix([-3.1666, 3.6667])
arr3 = np.around(3.1666, 2)
arr4 = np.floor([-3.1666, 3.6667])
arr5 = np.ceil([-3.1666, 3.6667])

print(arr1)
print(arr2)
print(arr3)
print(arr4)
print(arr5)
# Out:
# [-3.  3.]
# [-3.  3.]
# 3.17
# [-4.  3.]
# [-3.  4.]
